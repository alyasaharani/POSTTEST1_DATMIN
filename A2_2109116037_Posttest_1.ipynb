# %% [markdown]
# <a href="https://colab.research.google.com/github/alyasaharani/POSTTEST1_DATMIN/blob/main/A2_2109116037_Posttest_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Melakukan import pandas, seaborn dan plotly

# %%
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
# Buatlah datasetnya disini
df = pd.read_csv("ChurnBank.csv")

# %%
df
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 1         6684  711323283  Attrited Customer            57      M
# 2         4272  794707083  Attrited Customer            50      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 5         9597  715076358  Attrited Customer            57      M
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 8         5016  795599883  Attrited Customer            57      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# ...

# %% [markdown]
# ### Business Understanding
#
# Pada contoh kasus perusahaan yang bergerak di bidang asuransi pastinya memiliki tujuan untuk memberikan jaminan kepada pihak yang dijamin, agar dapat menerima sejumlah uang sebagai pengganti kerugian, yang mungkin diderita oleh yang dijamin, karena diakibatkan dari suatu peristiwa yang belum jelas, yaitu dengan menggunakan algoritma naive bayes.
#
# Terdapat pula dataset yang digunakan untuk menyimpan informasi yg dibutuhkan seperti data untuk kriteria calon nasabah, sehingga perusahaan asuransi dapat mengambil keputusan dalam menerapkan strategi yang tepat untuk menawarkan produk kepada calon nasabah berdasarkan kriteria nasabah yang sudah ada, adapun kriteria yang penting yaitu penghasilan nasabah untuk dapat menentukan jenis asuransi kepada calon nasabah. Dengan menggunakan metode algoritma Naive Bayes diharapkan bisa membantu perusahaan dalam pengelolaan data nasabah dengan cara mengklasifikasi data nasabah potensial bagi perusahaan.

# %% [markdown]
# #Data Understanding

# %%
# df1 isinya dataset dengan label target AttiredCustomer
df1 = df[df["Attrition_Flag"] < "AttritedCustomer" ]

# %%
df1
# Out:
#    Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0        6036  720010608  Attrited Customer            37      M
# 1        6684  711323283  Attrited Customer            57      M
# 2        4272  794707083  Attrited Customer            50      M
# 3        9759  709657533  Attrited Customer            44      M
# 4        4740  716625033  Attrited Customer            32      F
# 5        9597  715076358  Attrited Customer            57      M
# 6        5009  804829533  Attrited Customer            59      M
# 7        8200  712144158  Attrited Customer            53      F
# 8        5016  795599883  Attrited Customer            57      F
# 9        8350  709222008  Attrited Customer            41      M
#
#   Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0         Unknown         Single     $40K - $60K          Blue       10226.0
# 1      Uneducated        Married     $60K - $80K          Blue        2527.0
# ...

# %%
# df2 dengan label bukan Attrired customer
df2 = df[df["Attrition_Flag"] > "AttritedCustomer" ]

# %%
df2
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 10        8139  809844108  Existing Customer            48      M
# 11         176  716264358  Existing Customer            53      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
# 19        8226  713700258  Existing Customer            55      F
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 10       Doctorate         Single     $60K - $80K          Blue        8086.0
# 11      Uneducated        Married    $80K - $120K          Blue       26792.0
# ...

# %%
# df3 dengan tabel untuk usia dibawah 50 tahun
df3 = df[df["Customer_Age"] < 50]

# %%
df3
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 3         9759  709657533  Attrited Customer            44      M
# 4         4740  716625033  Attrited Customer            32      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 12        8020  778163508  Existing Customer            37      F
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 15        4563  809809008  Existing Customer            47      F
# 16       10084  718161708  Existing Customer            46      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# ...

# %%
# df4 untuk customer yang statusnya itu single
df4 = df[df["Marital_Status"] == "Single" ]

# %%
df4
# Out:
#     Unnamed: 0  CLIENTNUM     Attrition_Flag  Customer_Age Gender  \
# 0         6036  720010608  Attrited Customer            37      M
# 2         4272  794707083  Attrited Customer            50      M
# 4         4740  716625033  Attrited Customer            32      F
# 6         5009  804829533  Attrited Customer            59      M
# 7         8200  712144158  Attrited Customer            53      F
# 9         8350  709222008  Attrited Customer            41      M
# 10        8139  809844108  Existing Customer            48      M
# 13         357  711857733  Existing Customer            49      M
# 14        6562  720070383  Existing Customer            41      F
# 17        5725  771079833  Existing Customer            40      F
# 18        2587  711639708  Existing Customer            42      M
#
#    Education_Level Marital_Status Income_Category Card_Category  Credit_Limit
# 0          Unknown         Single     $40K - $60K          Blue       10226.0
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       20 non-null     int64
#  1   CLIENTNUM        20 non-null     int64
#  2   Attrition_Flag   20 non-null     object
#  3   Customer_Age     20 non-null     int64
#  4   Gender           20 non-null     object
#  5   Education_Level  20 non-null     object
#  6   Marital_Status   20 non-null     object
#  7   Income_Category  20 non-null     object
#  8   Card_Category    20 non-null     object
#  9   Credit_Limit     20 non-null     float64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.7+ KB
# None

# %% [markdown]
# Pada df.info() berisi untuk mengetahui kolom mana yang terdapat data hilang karena akan menampilkan beberapa info berupa data kolom yaitu : jumlah kolom, nama-nama kolom, jumlah data yang tidak kosong dan type data pada kolom tersebut.

# %%
#@title Opsional (nilai plus)
# Tampilkan nilai rata-rata, min,max, dan standar deviasi  untuk setiap kolom bertipe angka
# numerical adalah pengelompokkan untuk kolom bertipe angka
numerical = [var for var in df.columns if df[var].dtype!='O']
print('There are {} numerical variables\n'.format(len(numerical)))
print('The numerical variables are :', numerical)
# Out:
# There are 4 numerical variables
#
# The numerical variables are : ['Unnamed: 0', 'CLIENTNUM', 'Customer_Age', 'Credit_Limit']

# %%
# Melakukan pemanggilan hasil pengelompokkan
df[numerical]
# Out:
#     Unnamed: 0  CLIENTNUM  Customer_Age  Credit_Limit
# 0         6036  720010608            37       10226.0
# 1         6684  711323283            57        2527.0
# 2         4272  794707083            50        3495.0
# 3         9759  709657533            44        7793.0
# 4         4740  716625033            32        2761.0
# 5         9597  715076358            57       23714.0
# 6         5009  804829533            59       24621.0
# 7         8200  712144158            53        2370.0
# 8         5016  795599883            57        2404.0
# 9         8350  709222008            41        4742.0
# 10        8139  809844108            48        8086.0
# 11         176  716264358            53       26792.0
# 12        8020  778163508            37        5245.0
# 13         357  711857733            49       18584.0
# 14        6562  720070383            41        2429.0
# 15        4563  809809008            47        3111.0
# ...

# %%
# Menampilkan nilai rata-rata
df[numerical].mean()
# Out:
# Unnamed: 0      6.105100e+03
# CLIENTNUM       7.424893e+08
# Customer_Age    4.725000e+01
# Credit_Limit    8.114580e+03
# dtype: float64

# %%
# Menampilkan nilai min (paling kecil)
df[numerical].min()
# Out:
# Unnamed: 0            176.0
# CLIENTNUM       709222008.0
# Customer_Age           32.0
# Credit_Limit         1438.3
# dtype: float64

# %%
# Menampilkan nilai max (paling besar)
df[numerical].max()
# Out:
# Unnamed: 0          10084.0
# CLIENTNUM       809844108.0
# Customer_Age           59.0
# Credit_Limit        26792.0
# dtype: float64

# %%
# Menampilkan nilai standar deviasi
df[numerical].std()
# Out:
# Unnamed: 0      2.850304e+03
# CLIENTNUM       4.045524e+07
# Customer_Age    7.859791e+00
# Credit_Limit    8.331037e+03
# dtype: float64

# %% [markdown]
# ##### Visualisasi Comparison

# %%
sns.countplot(data=df,x="Attrition_Flag")
# Out:
# <AxesSubplot:xlabel='Attrition_Flag', ylabel='count'>

# %%
sns.countplot(data=df,y="Education_Level")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Education_Level'>

# %%
sns.countplot(data=df,y="Education_Level",hue="Gender")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Education_Level'>

# %% [markdown]
# Penjelasan pada tiap visualisasi comparison :
#
# *   Pada visualisasi pertama yaitu membuat visualisasi perbandingan yang menampilkan berapa banyak yang attired customer dan tidak pada Attrition_Flag.
# *   Pada visualisasi kedua yaitu membuat visualisasi perbandingan yang menampilkan berapa banyak Education level berdasarkan kategori-kategorinya. Yang dimana kategorinya berisi : Unknown, Uneducated, College, High School, Graduate, Post-Graduate, Doctorate.
# *   Pada visualisasi ketiga yaitu membuat visualisasi perbandingan yang menampilkan berapa banyak jumlah Education level berdasarkan gendernya, yang dimana pada gender sendiri berisi M (male) dan F (female).

# %% [markdown]
# ##### Visualisasi Distribution

# %%
sns.histplot(data=df,x="Customer_Age",kde=True)
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Count'>

# %%
sns.histplot(data=df,x="Credit_Limit",kde=True)
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Count'>

# %%
sns.boxplot(data=df,x="Customer_Age")
# Out:
# <AxesSubplot:xlabel='Customer_Age'>

# %%
sns.boxplot(data=df,x="Credit_Limit")
# Out:
# <AxesSubplot:xlabel='Credit_Limit'>

# %% [markdown]
# Penjelasan pada tiap visualisasi distribution :
#
# *   Pada visualisasi pertama dan kedua yaitu membuat visualisasi histogram untuk umur customer dan credit card limit dan di tambahkan "kde=True" agar pada histogram terdapat garis lengkungan yang menyesuaikan diagram batang pada histogram.
# *   Pada visualisasi ketiga dan keempat yaitu membuat visualisasi boxplot untuk customer dan credit card limit, boxplot merupakan salah satu visualisasi dalam statistik deskriptif untuk menggambarkan secara grafik dari data numerik. Boxplot sendiri dapat membantu untuk memahami karakteristik dari distribusi data. Selain untuk melihat derajat penyebaran data (yang dapat dilihat dari tinggi/panjang boxplot) juga dapat digunakan untuk menilai kesimetrisan sebaran data. Panjang kotak menggambarkan tingkat penyebaran atau keragaman data pengamatan, sedangkan letak median dan panjang whisker menggambarkan tingkat kesimetrisannya.

# %% [markdown]
# ##### Visualisasi Relationship

# %%
# Buatlah scatterplot untuk umur customer dan credit card limit
sns.scatterplot(data=df2,x="Customer_Age",y="Credit_Limit")
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Credit_Limit'>

# %% [markdown]
# ##### Visualisasi Composition

# %%
# Buatlah pieplot untuk Income Category & Education Level

# %%
# Membuat pieplot untuk Income Category
px.pie(df,names="Income_Category")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Membuat pieplot untuk Education Level
px.pie(df,names="Education_Level")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Opsional (Nilai Plus)

# %%
# Buatlah visualisasi boxplot Credit Card Limit dengan Jenis Kelamin sebagai pemisahnya (color)
sns.boxplot(data=df,x="Credit_Limit", y="Gender")
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Gender'>

# %%
# Buatlah visualisasi boxplot Credit Card Limit dengan Attrition Flag sebagai pemisahnya (color)
sns.boxplot(data=df, x="Credit_Limit", y="Attrition_Flag")
# Out:
# <AxesSubplot:xlabel='Credit_Limit', ylabel='Attrition_Flag'>

# %%
# Buatlah visualisasi boxplot Age dengan Attrition Flag sebagai pemisahnya (color)
sns.boxplot(data=df,x="Customer_Age", y="Attrition_Flag")
# Out:
# <AxesSubplot:xlabel='Customer_Age', ylabel='Attrition_Flag'>

# %%
# Buatlah visualisasi countplot  Attrition Flag dengan jenis kelamin sebagai pemisahnya (color)
sns.countplot(data=df,y="Attrition_Flag",hue="Gender")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Attrition_Flag'>

# %%
# Buatlah visualisasi countplot  Attrition Flag dengan jenis kelamin sebagai pemisahnya (color)
sns.countplot(data=df,y="Attrition_Flag",hue="Gender")
# Out:
# <AxesSubplot:xlabel='count', ylabel='Attrition_Flag'>

# %%
# Buatlah visualisasi heatmap untuk Setiap variabel numerik yang ada
# Membuat korelasi/hubungan antara setiap variabel yang bernilai numerik
corr = df.corr()

# %%
# Membuat visualisasi dari heatmap dengan menggunakan warna biru
sns.heatmap(corr, cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Algoritma Naive Bayes dan Preprocessing (pengenalan)

# %%
# sebelum membuat algoritma pertama tama buatlah dataset baru dengan ketentuan
# mengambil dataset df
# Menghapus kolom Unnamed: 0, CLIENTNUM, Umur, dan Limit Kartu Kredit (initinya yang berupa primary key dan bukan tipe kategori)
# dataset dengan kolom yang sudah dihapus tadi kemudian disimpan di dataframe baru (df baru)
categorical = [var for var in df.columns if df[var].dtype=='O']
print('There are {} categorical variables\n'.format(len(categorical)))
print('The categorical variables are :\n\n', categorical)
# Out:
# There are 6 categorical variables
#
# The categorical variables are :
#
#  ['Attrition_Flag', 'Gender', 'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category']

# %%
# Menghapus kolom Unnamed: 0, CLIENTNUM, Umur, dan Limit Kartu Kredit (initinya yang berupa primary key dan bukan tipe kategori)
x = df.drop(["Unnamed: 0","CLIENTNUM","Customer_Age","Credit_Limit"], axis=1)
x.head(20)
# Out:
#        Attrition_Flag Gender Education_Level Marital_Status Income_Category  \
# 0   Attrited Customer      M         Unknown         Single     $40K - $60K
# 1   Attrited Customer      M      Uneducated        Married     $60K - $80K
# 2   Attrited Customer      M         College         Single    $80K - $120K
# 3   Attrited Customer      M     High School        Unknown         $120K +
# 4   Attrited Customer      F        Graduate         Single  Less than $40K
# 5   Attrited Customer      M   Post-Graduate        Unknown    $80K - $120K
# 6   Attrited Customer      M     High School         Single     $60K - $80K
# 7   Attrited Customer      F        Graduate         Single  Less than $40K
# 8   Attrited Customer      F      Uneducated        Married         Unknown
# 9   Attrited Customer      M         Unknown         Single    $80K - $120K
# 10  Existing Customer      M       Doctorate         Single     $60K - $80K
# ...

# %%
# Cara lain untuk menghapus kolom yang bukan bertipe kategori
df[categorical].head(20)
# Out:
#        Attrition_Flag Gender Education_Level Marital_Status Income_Category  \
# 0   Attrited Customer      M         Unknown         Single     $40K - $60K
# 1   Attrited Customer      M      Uneducated        Married     $60K - $80K
# 2   Attrited Customer      M         College         Single    $80K - $120K
# 3   Attrited Customer      M     High School        Unknown         $120K +
# 4   Attrited Customer      F        Graduate         Single  Less than $40K
# 5   Attrited Customer      M   Post-Graduate        Unknown    $80K - $120K
# 6   Attrited Customer      M     High School         Single     $60K - $80K
# 7   Attrited Customer      F        Graduate         Single  Less than $40K
# 8   Attrited Customer      F      Uneducated        Married         Unknown
# 9   Attrited Customer      M         Unknown         Single    $80K - $120K
# 10  Existing Customer      M       Doctorate         Single     $60K - $80K
# ...

# %%
#duplicate dataframe
df_baru = df[categorical]

#show data
df_baru.head(20)
# Out:
#        Attrition_Flag Gender Education_Level Marital_Status Income_Category  \
# 0   Attrited Customer      M         Unknown         Single     $40K - $60K
# 1   Attrited Customer      M      Uneducated        Married     $60K - $80K
# 2   Attrited Customer      M         College         Single    $80K - $120K
# 3   Attrited Customer      M     High School        Unknown         $120K +
# 4   Attrited Customer      F        Graduate         Single  Less than $40K
# 5   Attrited Customer      M   Post-Graduate        Unknown    $80K - $120K
# 6   Attrited Customer      M     High School         Single     $60K - $80K
# 7   Attrited Customer      F        Graduate         Single  Less than $40K
# 8   Attrited Customer      F      Uneducated        Married         Unknown
# 9   Attrited Customer      M         Unknown         Single    $80K - $120K
# 10  Existing Customer      M       Doctorate         Single     $60K - $80K
# ...

# %%
# Buatlah sebuah fungsi naive bayes dengan ketentuan
# Mengambil data dari dataframe yang telah diproses pada blok sebelumnya (diatas)
# Nama fungsinya adalah naive_bayes
# Mengambil 1 saja parameter yaitu sebuah list berisi kategori

# Outputnya berupa prediksi Attrited Customer atau Existing Customer
# Outputnya berupa tuple (_hasilnya, persentasenya berapa) contoh (Existing Customer, 0.004)

# Tidak boleh menggunakan library manapun selain pandas dan numpy



# contoh
# def naive_bayes(prediksi:list)-> tuple :
#   ........

# jadi nanti saat saya coba masukan data 
# naive_bayes(["F",	"Uneducated","Single", "Unknown	Blue"]) akan keluar tuple berupa ("Attired Customer", 0.002)

# %%
def naive_bayes(prediksi:list)-> tuple :
    attrited = df_baru[df_baru["Attrition_Flag"]=="Attrited Customer"]
    existing = df_baru[df_baru["Attrition_Flag"]=="Existing Customer"]
    
    # prior probability
    attrited_prior = len(attrited) / len(df_baru)
    existing_prior = len(existing) / len(df_baru)
    
    # likelihood
    for i in range(len(prediksi)):
        attrited_subset = attrited[attrited.iloc[:,i]==prediksi[i]]
        existing_subset = existing[existing.iloc[:,i]==prediksi[i]]
        
        attrited_posterior = (len(attrited_subset) + 1) / (len(attrited) + len(df_baru.iloc[:,i].unique()))
        existing_posterior = (len(existing_subset) + 1) / (len(existing) + len(df_baru.iloc[:,i].unique()))
        
        if i == 0:
            attrited_likelihood = attrited_posterior
            existing_likelihood = existing_posterior
        else:
            attrited_likelihood *= attrited_posterior
            existing_likelihood *= existing_posterior
    
    # posterior probability
    attrited_posterior = attrited_prior * attrited_likelihood
    existing_posterior = existing_prior * existing_likelihood
    
    # normalize posterior probability
    persentasenya = existing_posterior / (attrited_posterior + existing_posterior)
    hasilnya = "Existing Customer" if persentasenya >= 0.5 else "Attrited Customer"
    
    return (hasilnya, persentasenya)

# %%
hasil = naive_bayes(["F", "Uneducated", "Single", "Unknown", "Blue"])
print(hasil)
# Out:
# ('Attrited Customer', 0.25)
